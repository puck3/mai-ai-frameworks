# %%
import kagglehub

# %%
class_path = kagglehub.dataset_download("tawfikelmetwally/employee-dataset")

print("Path to dataset files:", class_path)
# Out:
# Path to dataset files: /home/kirill/.cache/kagglehub/datasets/tawfikelmetwally/employee-dataset/versions/1

# %%
# !ls $class_path
# Out:
# Employee.csv

# %%
# !cp $class_path/Employee.csv ./datasets/Employee.csv

# %%
reg_path = kagglehub.dataset_download("ruchikakumbhar/calories-burnt-prediction")

print("Path to dataset files:", reg_path)
# Out:
# Path to dataset files: /home/kirill/.cache/kagglehub/datasets/ruchikakumbhar/calories-burnt-prediction/versions/1

# %%
# !ls $reg_path
# Out:
# calories.csv

# %%
# !cp $reg_path/calories.csv ./datasets/calories.csv

# %%
# !ls ./datasets
# Out:
# calories.csv  Employee.csv
